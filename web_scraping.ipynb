# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'}
url='https://www.amazon.de/dp/B07S1D8VM2/ref=sr_1_3?crid=3GZPQGVI8BIT7&keywords=xiaomi+staubsauger+s6&qid=1581281593&sprefix=xiaomi+staubsauger%2Caps%2C166&sr=8-3'

# %%
response=requests.get(url, headers=headers)
import csv
from bs4 import BeautifulSoup

# %%
print(response.text)
# Out:
# <!doctype html><html lang="de-de" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type='text/javascript'>var ue_t0=ue_t0||+new Date();</script><!-- sp:feature:cs-optimization -->
# <meta http-equiv='x-dns-prefetch-control' content='on'><link rel="preconnect" href="https://images-eu.ssl-images-amazon.com" crossorigin><link rel="preconnect" href="https://m.media-amazon.com" crossorigin><link rel="preconnect" href="https://completion.amazon.com" crossorigin><script type='text/javascript'>
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
soup=BeautifulSoup(response.content, features="lxml")

# %%
product_name=soup.select("#productTitle")[0].get_text().strip()

# %%
price=soup.select("#priceblock_ourprice")[0].get_text().strip()

# %%
color=soup.select(".selection")[0].get_text().strip()

# %%
sold_by=soup.select("#merchant-info")[0].get_text().strip()

# %%
brand=soup.select("#bylineInfo")[0].get_text()

# %%
jsonObject={'product_name':product_name, 'price':price, 'brand':brand, 'color':color, 'sold_by':sold_by}

print(json.dumps(jsonObject, indent=2))
# Out:
# {
#   "product_name": "Mi Roborock S6 schwarz, Wischfunktion, Saugleistung 2000Pa, Virtuelle W\u00e4nde, Steuerung per App, 360\u00b0 Abdeckung, Intelligente Wegplanung; Echtzeit Raumkarten, Zeitplanreinigung, Hindernis\u00fcberwindung",
#   "price": "485,97\u00a0\u20ac",
#   "brand": "Xiaomi",
#   "color": "Mi Roborock S6 Black",
#   "sold_by": "Versandt und verkauft von Amazon in recycelbarer Verpackung."
# }
