# %%
import requests
from bs4 import BeautifulSoup
from urllib3.exceptions import ProtocolError
import csv


def get_page(url):
    response=requests.get(url)
    if not response.ok:
        print('Server responded:', response.status_code)
    else:
        soup=BeautifulSoup(response.text,'lxml')
    return soup

def get_detail_data(soup):
    #title
    #price
    #location
    #shipping
    #sellername
    #condition
    #color
    try:
        try:
            title = soup.find('h1', id='itemTitle').text.strip().replace('Details about  \xa0', '')
        except:
            title=soup.find('h3',attrs={'class':'s-item__title s-item__title--has-tags'}).text.strip().replace('Details about  \xa0', '')
    except:
        title=''
    print(title)
    
    try:
        try:
            p=soup.find('span', id='prcIsum').text.strip()
        except:
            p=soup.find('span', id='mm-saleDscPrc').text.strip()
        currency, price = p.split(' ')
    except:
        currency=''
        price=''
    print(price)
    print(currency)
    try:
        location = soup.find('div', attrs = {'class':'iti-eu-bld-gry'}).get_text().strip()
    except:
        location=''
    
    try:
        try:
            shipping_cost=soup.find('span', attrs={'id':'fshippingCost'}).get_text().strip()
        except:
            shipping_cost=soup.find('span', attrs={'id':'convetedPriceId'}).get_text().strip()
    except:
        shipping_cost= ''
    
    try:
        sellername = soup.find('span', attrs = {'class':'mbg-nw'}).get_text().strip()
    except:
        sellername = ''
    
    try:
        try:
            condition = soup.find('div', attrs = {'class':"u-flL condText  "}).get_text().strip()
        except:
            condition=soup.finf('div',attrs={'id':"vi-itm-cond"}).get_text().strip()
    except:
        condition= ''
    
    try:
        color=soup.find('select', attrs={'id':'msku-sel-1'}).get_text().strip().replace('- Select -', '')
    except:
        color= ''
    
    
    data={
        'title': title,
        'price': price,
        'location':location,
        'shipping_cost':shipping_cost,
        'sellername':sellername,
        'condition':condition,
        'color':color
        
    }
    
    return data


        
def get_index_data(soup):
    try:
        links=soup.find_all('a', class_='s-item__link')
    except:
        links=[]
        
    urls=[item.get('href') for item in links]
    
    return urls

import time

time.sleep(2.4)
print("Printed after 2.4 seconds.")

def write_csv(data, url):
    with open('nintendo14032020.csv', 'a', encoding='utf-8') as csvfile:
        writer=csv.writer(csvfile)
        
        row=[data['title'], data['price'],data['location'],data['shipping_cost'],data['sellername'],data['condition'],data['color'],url]
    
        writer.writerow(row)

def main():
    
    url="https://www.ebay.com/sch/i.html?_nkw=nintendo+switch&_pgn={}"
    page_num = 1
    while page_num<=50:
        response = requests.get(url.format(page_num))
        if response.status_code == 404: # break once the page is not found
            break
        print("Scraping Page Number {}".format(page_num))
        soup = BeautifulSoup(response.text,"lxml")
    
        page_num += 1
  
    products= get_index_data(get_page(url))
    
    for link in products:
        data=get_detail_data(get_page(link))
        write_csv(data,link)
    


if __name__=='__main__':
    main()
# Out:
# Printed after 2.4 seconds.
# Scraping Page Number 1
# Scraping Page Number 2
# Scraping Page Number 3
# Scraping Page Number 4
# Scraping Page Number 5
# Scraping Page Number 6
# Scraping Page Number 7
# Scraping Page Number 8
# Scraping Page Number 9
# Scraping Page Number 10
# Scraping Page Number 11
# Scraping Page Number 12
# Scraping Page Number 13
# Scraping Page Number 14
# Scraping Page Number 15
# Scraping Page Number 16
# Scraping Page Number 17
# Scraping Page Number 18
# Scraping Page Number 19
# Scraping Page Number 20
# Scraping Page Number 21
# Scraping Page Number 22
# Scraping Page Number 23
# Scraping Page Number 24
# Scraping Page Number 25
# Scraping Page Number 26
# Scraping Page Number 27
# Scraping Page Number 28
# Scraping Page Number 29
# Scraping Page Number 30
# Scraping Page Number 31
# Scraping Page Number 32
# Scraping Page Number 33
# Scraping Page Number 34
# Scraping Page Number 35
# Scraping Page Number 36
# Scraping Page Number 37
# Scraping Page Number 38
# Scraping Page Number 39
# Scraping Page Number 40
# Scraping Page Number 41
# Scraping Page Number 42
# Scraping Page Number 43
# Scraping Page Number 44
# Scraping Page Number 45
# Scraping Page Number 46
# Scraping Page Number 47
# Scraping Page Number 48
# Scraping Page Number 49
# Scraping Page Number 50
# Console Nintendo Switch Lite Zacian and Zamazenta Limited Edition - New
# 229.00
# GBP
# Nintendo Switch 32GB Gray + Fire Emblem: Three Houses + Case + Screen Protector
#
#
# Nintendo Switch with Gray Joy‑Con - HAC-001(-01)
# $399.00
# US
# NINTENDO SWITCH Lite Console System Pokemon Zacian Zamazenta Limited Edition NEW
# $297.46
# US
# Nintendo Switch 32GB Replacement Console (Hackable/Unpatched) A+ Tablet Only
# $269.00
# US
# Animal Crossing: New Horizons Nintendo Switch Console | SPECIAL EDITION
#
#
# NEW Nintendo Switch Dragon Quest XI S Lotto Limited Edition JAPAN  Joy-con,Dock
# $100.50
# US
# NEW Nintendo Switch Dragon Quest XI S Lotto Limited Edition JAPAN Joy-con,Dock
# 85.58
# GBP
#  New Nintendo Switch Console Red Blue Joy-Con Game Wireless Controller
# $340.00
# US
# NINTENDO SWITCH DIABLO LIMITED EDITION TABLET ONLY NEAR MINT CONDITION
# 175.00
# GBP
# NEW Nintendo Switch Dragon Quest XI S Lotto Limited Edition JAPAN Joy-con,Dock
# $165.59
# AU
# Nintendo Switch 32GB Console w/ Custom Shell Joy-Con (Unpatched)
# $349.00
# US
# Nintendo Switch 32GB Neon Red/Neon Blue Console (Atmosphere) + 128GB MicroSD
# 380.00
# GBP
# Nintendo Switch Lite Zashian and Zamazenta or Pokemon Sword Shield Game Soft JP
# $150.00
# US
# New Nintendo Switch Lite Console System Zacian Zamazenta JAPAN import Pokemon
# $299.99
# US
# Nintendo Switch Lite Grey Handheld System - Brand New
# 214.99
# GBP
# Nintendo Switch Console - Neon
# 462.58
# GBP
# New Nintendo Switch Console System Monster Hunter XX Double Cross Special Pack
# $899.99
# US
# Nintendo Switch Lite console Pokemon Sword Shield Zacian Zamazenta Japan NEW
# $230.56
# US
# NEW Nintendo Switch Dragon Quest XI S Lotto Limited Edition Joy-con + Dock
# 245.49
# GBP
# Console Nintendo Switch V1 (première version) NEUF RARE
#
#
# New Nintendo Switch Lite Console Gray Portable Game Machine F/S from Japan
# $284.92
# US
# NEW Nintendo Switch Dragon Quest XI S Lotto Limited Edition  Joy-con + Dock
# $298.00
# US
# Nintendo Switch Animal Crossing New Horizons Console System Japan version
# $532.00
# US
# New Nintendo Switch Lite Gray F/S from Japan
# $286.99
# US
# Nintendo Switch Consoles Various types Game JAPAN Select type
# $385.00
# US
# New Nintendo Switch Console only Nintendo Switch Tablet Japan
# $259.99
# US
# Nintendo Switch Consoles Various types Game JAPAN Select type
# 302.31
# GBP
# NEW Nintendo Switch Lite Console Yellow ,Turquoise Blue ,Gray Zacyan Zamazenta
# $217.99
# US
# Nintendo Switch Neon Red/Blue Joy-Controller Boxed + Memory Card
#
#
# NINTENDO SWITCH CONSOLE BUNDLE. NEON RED/ BLUE.
#
#
# UNPATCHED Version 9.1 Mod Grade A Hackable Nintendo Switch Console Mario Box Low
#
#
# Nintendo Switch: Animal Crossing: New Horizons Edition Console SHIPS 3/19
# $425.00
# US
# Nintendo Switch Console Système Super Smash Bros. Brothers Japon Special
# 700.00
# EUR
# Nintendo Switch Lite Zashian and Zamazenta Edition Console f/s japan
# $210.98
# US
# Nintendo Switch Disney Tsum Tsum Festival Console Only
# $349.99
# US
# Nintendo Switch Grey Joy-Con Console & New Super Mario Bros. U Deluxe Bundle New
# $519.95
# AU
# NEW pre-order Nintendo Switch Lite coral Japan free shipping F/S
# $275.00
# US
# Console Nintendo Switch Lite Turquoise Handheld System- 2019 Model- Sealed Box
# 155.00
# GBP
# Nintendo Switch Splatoon 2 sets
# $721.42
# US
# ESP Ra.De. Psi Limited Edition BEEP Special Edition Nintendo Switch Japan
# $159.99
# US
# Nintendo Switch Lite gray  nintendo mario super smash bros
# $307.80
# US
# Pre Nintendo Switch Animal Crossing New Horizons Special Edition Joy-con Joycon
# $181.00
# US
# New Nintendo Switch Console only Nintendo switch Tablet Japan
# 214.19
# GBP
# Neuf Nintendo Switch Console Seulement Nintendo Interrupteur Tablette Japon
# 245.11
# EUR
# Nintendo Switch Lite Zacian and Zamazenta Pokemon Shield Pack Limited Brand New
# $399.00
# US
# Nintendo Switch Consoles Various types Game JAPAN Select type
# $601.39
# AU
# Nintendo Switch Disney Tsum Tsum Festival Console
# 288.33
# GBP
# 【NEW - small stock】Nintendo Switch Latest Model Neon Red&Blue Japan 732
# $352.00
# US
# Nintendo Switch Animal Crossing New Horizons Special Edition - BUNDLE
# $500.00
# US
# Console Nintendo Switch Super Smash Bros Ultimate Edition Pack
# 400.00
# EUR
# Nintendo Switch Animal Crossing: New Horizon Special Edition Console With Case!
#
#
# Nintendo Switch Lite gray
# $279.44
# US
# Nintendo Switch Super Smash Bros Ultimate Limited Edition Bundle NEW
# $593.40
# US
# Nintendo Switch Console Animal Crossing: New Horizons Edition | IN HAND SHIP NOW
# $439.99
# US
# Nintendo Switch Console System Super Smash Bros. brothers JAPAN SPECIAL
# 623.45
# GBP
# Nintendo Switch Game console Joy-Con (L) / (R) gray Japan import
# $369.94
# US
# Nintendo Switch Animal Crossing New Horizon Special Edition Console BRAND NEW
# $431.11
# US
# Nintendo Switch Pokemon Let's Go Pikachu Limited Edition Bundle NEW
# $589.50
# US
# Nintendo Switch 32GB Animal Crossing New Horizons Edition Console Ready To Ship!
# $455.00
# US
# NINTENDO SWITCH (NEON BLUE / NEON RED)Japan Domestic
# $396.89
# US
